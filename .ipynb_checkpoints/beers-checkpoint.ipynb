# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 15]

# %%
data = pd.read_csv('recipeData.csv' , encoding='latin-1')
styles = pd.read_csv('styleData.csv', encoding='latin-1')

# %%
styles.head()
# Out:
#                     Style  StyleID
# 0                 Altbier        1
# 1  Alternative Grain Beer        2
# 2  Alternative Sugar Beer        3
# 3      American Amber Ale        4
# 4     American Barleywine        5

# %%
data.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# ...

# %%
print(len(data))
print(len(data['Style'].unique()))
# Out:
# 73861
# 176

# %%
popular_beers = data['Style'].value_counts()[:10]

# %%
popular_beers
# Out:
# American IPA            11940
# American Pale Ale        7581
# Saison                   2617
# American Light Lager     2277
# American Amber Ale       2038
# Blonde Ale               1753
# Imperial IPA             1478
# American Stout           1268
# Irish Red Ale            1204
# American Brown Ale       1152
# Name: Style, dtype: int64

# %%
popular_beers_names = popular_beers.index
popular_beers_popularit = popular_beers.values

x = np.arange(len(popular_beers_names))

plt.bar(x, popular_beers_popularit)
plt.ylabel('Popularita')
plt.xlabel('Typ')
plt.xticks(x, popular_beers_names)
plt.show()

# %%
data = data.drop(['BeerID','Name', 'URL', 'Style'], axis=1)

# %%
data.head()
# Out:
#    StyleID  Size(L)     OG     FG   ABV    IBU  Color  BoilSize  BoilTime  \
# 0       45    21.77  1.055  1.013  5.48  17.65   4.83     28.39        75
# 1       85    20.82  1.083  1.021  8.16  60.65  15.64     24.61        60
# 2        7    18.93  1.063  1.018  5.91  59.25   8.98     22.71        60
# 3        7    22.71  1.061  1.017  5.80  54.48   8.50     26.50        60
# 4       20    50.00  1.060  1.010  6.48  17.84   4.57     60.00        90
#
#    BoilGravity  Efficiency  MashThickness        SugarScale BrewMethod  \
# 0        1.038        70.0            NaN  Specific Gravity  All Grain
# 1        1.070        70.0            NaN  Specific Gravity  All Grain
# 2          NaN        70.0            NaN  Specific Gravity    extract
# 3          NaN        70.0            NaN  Specific Gravity  All Grain
# 4        1.050        72.0            NaN  Specific Gravity  All Grain
#
#    PitchRate  PrimaryTemp PrimingMethod   PrimingAmount
# ...

# %%
data = data.fillna(data.mean())

# %%
data.head()
# Out:
#    StyleID  Size(L)     OG     FG   ABV    IBU  Color  BoilSize  BoilTime  \
# 0       45    21.77  1.055  1.013  5.48  17.65   4.83     28.39        75
# 1       85    20.82  1.083  1.021  8.16  60.65  15.64     24.61        60
# 2        7    18.93  1.063  1.018  5.91  59.25   8.98     22.71        60
# 3        7    22.71  1.061  1.017  5.80  54.48   8.50     26.50        60
# 4       20    50.00  1.060  1.010  6.48  17.84   4.57     60.00        90
#
#    BoilGravity  Efficiency  MashThickness        SugarScale BrewMethod  \
# 0     1.038000        70.0       2.127235  Specific Gravity  All Grain
# 1     1.070000        70.0       2.127235  Specific Gravity  All Grain
# 2     1.353955        70.0       2.127235  Specific Gravity    extract
# 3     1.353955        70.0       2.127235  Specific Gravity  All Grain
# 4     1.050000        72.0       2.127235  Specific Gravity  All Grain
#
#    PitchRate  PrimaryTemp PrimingMethod   PrimingAmount
# ...

# %%
data = pd.get_dummies(data, columns=['SugarScale', 'BrewMethod'])

# %%
len(data['PrimingMethod'].unique())
# Out:
# 875

# %%
len(data['PrimingAmount'].unique())
# Out:
# 1898

# %%
73861 / len(data['PrimingAmount'].unique())
# Out:
# 38.91517386722866

# %%
data.head()
# Out:
#    StyleID  Size(L)     OG     FG   ABV    IBU  Color  BoilSize  BoilTime  \
# 0       45    21.77  1.055  1.013  5.48  17.65   4.83     28.39        75
# 1       85    20.82  1.083  1.021  8.16  60.65  15.64     24.61        60
# 2        7    18.93  1.063  1.018  5.91  59.25   8.98     22.71        60
# 3        7    22.71  1.061  1.017  5.80  54.48   8.50     26.50        60
# 4       20    50.00  1.060  1.010  6.48  17.84   4.57     60.00        90
#
#    BoilGravity         ...          PitchRate  PrimaryTemp  PrimingMethod  \
# 0     1.038000         ...           0.750468    17.780000     corn sugar
# 1     1.070000         ...           0.750468    19.175641            NaN
# 2     1.353955         ...           0.750468    19.175641            NaN
# 3     1.353955         ...           0.750468    19.175641            NaN
# 4     1.050000         ...           0.750468    19.000000     Sukkerlake
#
#     PrimingAmount SugarScale_Plato SugarScale_Specific Gravity  \
# ...

# %%
data = data.drop(['PrimingAmount','PrimingMethod'], axis=1)

# %%
data = data.sample(frac=1)
cnt = data.shape[0]
index1 = int(np.ceil(cnt * 0.7))
index2 = int(np.ceil(cnt * 0.85))
data_train = data.iloc[1:index1]
data_eval = data.iloc[index1+1:index2]
data_test = data.iloc[index2+1:]
print('Sizes:\nTraining set - %d\nEval set       - %d\nTest set     - %d' % (data_train.shape[0], data_eval.shape[0], data_test.shape[0]))
# Out:
# Sizes:
# Training set - 51702
# Eval set       - 11078
# Test set     - 11078

# %%
Y_train = data_train['StyleID'].values
# Y_train = np.reshape(Y_train, (1, Y_train.shape[0]))
Y_test = data_test['StyleID'].values 
# Y_test = np.reshape(Y_test, (1, Y_test.shape[0]))
Y_eval = data_eval['StyleID'].values 
# Y_eval = np.reshape(Y_eval, (1, Y_eval.shape[0]))

data_train = data_train.drop(['StyleID'], axis=1)
data_test = data_test.drop(['StyleID'], axis=1)
data_eval = data_eval.drop(['StyleID'], axis=1)


X_train = data_train.as_matrix()
X_test = data_test.as_matrix()
X_eval = data_eval.as_matrix()

# %%
np.save('Y_train',Y_train)
np.save('Y_test',Y_test)
np.save('Y_eval',Y_eval)

np.save('X_train',X_train)
np.save('X_test',X_test)
np.save('X_eval',X_eval)

# %%
# %ls
# Out:
# X_eval.npy        Y_eval.npy        beers.ipynb       simplenet.ipynb
# X_test.npy        Y_test.npy        beersimple.ipynb  styleData.csv
# X_train.npy       Y_train.npy       recipeData.csv
